# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('..'))

# %%
from scripts.eda import *

# %% [markdown]
# ### EDA for CreditCard_data

# %%
data_path = '/home/nahomnadew/Desktop/10x/week8/Adey_Inoviation_Inc/Data/cleaned/creditcard.csv'

# %%
data = CreditCardEDA(data_path)

# %%
data.load_data()
# Out:
# 2025-02-07 20:36:29,912 - INFO - ✅ Data loaded successfully from /home/nahomnadew/Desktop/10x/week8/Adey_Inoviation_Inc/Data/missingHandled/creditcard.csv

# %%
data.plot_fraud_distribution()
# Out:
# 2025-02-07 20:36:52,935 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-02-07 20:36:53,014 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
data.correlation_heatmap()

# %% [markdown]
# ### EDA for IPAddress_Data

# %%
data_path2 = '/home/nahomnadew/Desktop/10x/week8/Adey_Inoviation_Inc/Data/cleaned/IpAddress_to_Country.csv'

# %%
data2 = IPGeolocationEDA(data_path2)

# %%
data2.load_data()
# Out:
# 2025-02-07 20:39:21,172 - INFO - ✅ Data loaded successfully from /home/nahomnadew/Desktop/10x/week8/Adey_Inoviation_Inc/Data/missingHandled/IpAddress_to_Country.csv

# %%
data2.plot_country_distribution()
# Out:
# /home/nahomnadew/Desktop/10x/week8/Adey_Inoviation_Inc/scripts/eda.py:67: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=country_counts.values, y=country_counts.index, palette="viridis")

# %% [markdown]
# ### EDA for Fraud-data

# %%
data_path3 = '/home/nahomnadew/Desktop/10x/week8/Adey_Inoviation_Inc/Data/cleaned/Fraud_Data.csv'

# %%
data3 = FraudDataEDA(data_path3)

# %%
data3.load_data()
# Out:
# 2025-02-07 20:41:23,305 - INFO - ✅ Data loaded successfully from /home/nahomnadew/Desktop/10x/week8/Adey_Inoviation_Inc/Data/missingHandled/Fraud_Data.csv

# %%
data3.summary_statistics()
# Out:
# 2025-02-07 20:41:43,794 - INFO - 📊 Summary Statistics:
#              user_id  purchase_value            age    ip_address  \
# count  151112.000000   151112.000000  151112.000000  1.511120e+05
# mean   200171.040970       36.935372      33.140704  2.152145e+09
# std    115369.285024       18.322762       8.617733  1.248497e+09
# min         2.000000        9.000000      18.000000  5.209350e+04
# 25%    100642.500000       22.000000      27.000000  1.085934e+09
# 50%    199958.000000       35.000000      33.000000  2.154770e+09
# 75%    300054.000000       49.000000      39.000000  3.243258e+09
# max    400000.000000      154.000000      76.000000  4.294850e+09
#
#                class
# count  151112.000000
# mean        0.093646
# std         0.291336
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
data3.plot_numerical_distributions()

# %%
data3.plot_categorical_distributions()
# Out:
# 2025-02-07 20:43:16,894 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-02-07 20:43:20,677 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-02-07 20:52:28,937 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-02-07 20:52:32,644 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ---------------------------------------------------------------------------
# ...

# %%
data3.plot_fraud_distribution()
# Out:
# 2025-02-07 20:41:58,848 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-02-07 20:41:58,885 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
